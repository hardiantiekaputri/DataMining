# %% [markdown]
# <a href="https://colab.research.google.com/github/hardiantiekaputri/DataMining/blob/main/DBSCAN_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

data = load_breast_cancer()
X = data.data
scaler = StandardScaler()
X = scaler.fit_transform(X)

dbscan_clustering = DBSCAN(eps=0.5, min_samples=5)
dbscan_clustering.fit(X)

df = pd.DataFrame(X, columns=data.feature_names)
df['Cluster'] = dbscan_clustering.labels_

sns.scatterplot(data=df, x=data.feature_names[0], y=data.feature_names[1], hue='Cluster')
plt.xlabel(data.feature_names[0])
plt.ylabel(data.feature_names[1])
plt.title("DBSCAN Clustering Results")
plt.show()
